# %% [markdown]
# # KiteML Tutorial: Classification
#
# This notebook demonstrates binary classification training, diagnostics, and prediction with **KiteML**.

# %%
import pandas as pd
from kiteml import train

# Create synthetic churn dataset
df = pd.DataFrame({
    "age": [25, 45, 35, 50, 23, 62, 48, 29],
    "income": [50000, 90000, 62000, 110000, 48000, 125000, 98000, 54000],
    "credit_score": [650, 720, 680, 800, 610, 750, 710, 640],
    "churn": [1, 0, 0, 0, 1, 0, 0, 1]
})

# Train classification model
result = train(data=df, target="churn", problem_type="classification")

print(result.summary())
print(result.diagnostics())
